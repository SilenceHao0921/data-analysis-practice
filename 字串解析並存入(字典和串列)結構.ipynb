# %% [markdown]
# # 2025/8/7 字串解析並存入(字典和串列)結構

# %% [markdown]
# ## 字串解析並存入字典結構

# %%
import datetime

f = open('學生資料表.txt', 'r', encoding="UTF-8")
# print(type(f)) # <class '_io.TextIOWrapper'>
# print(dir(f))
data_string = f.read() # 變成一個很大的字串
# print(repr(a))
f.close()

# 利用跳行轉義字符\n切割字串
lines = data_string.split('\n')
# print(lines)

# 创建字典列表
students = []
for line in lines:
    if line.strip():  # 如果是空行就跳過
        parts = line.split()
        # 处理姓名可能包含空格的情况（虽然本例中没有）
        # 假设格式固定为：姓名 学号 成绩一 成绩二 生日
        name = parts[0]
        student_id = parts[1]
        score1 = int(parts[2])
        score2 = int(parts[3])
        birthday = parts[4]

        student = {
            '姓名': name,
            '學號': student_id,
            '成績一': score1,
            '成績二': score2,
            '生日': birthday
        }
        students.append(student)

# 動態新增平均成績欄位
for student in students:
    student['平均'] = ( student['成績一'] + student['成績二'] ) / 2
    #print(student)

# 動態新增年齡欄位
for student in students:
    # step1. 把生日字串變成日期結構  'strftime'日期變字串, 'strptime'字串變日期
    我的生日 = datetime.datetime.strptime(student['生日'],'%Y/%m/%d')
    # step2. 得到今天日期結構
    今天日期 = datetime.datetime.now()
    # step3. 算年齡
    age = 今天日期.year - 我的生日.year
    # step4. 如果生日還沒過  年齡要減一
    if 今天日期 < datetime.datetime(今天日期.year,我的生日.month,我的生日.day) :
        age -= 1
    student['年齡'] = age

a = sorted(students,key=lambda x:(x['年齡'], x['平均']),reverse=True)
for student in a:
    print(student)
# Out:
# {'姓名': '詹昇諭', '學號': '24', '成績一': 78, '成績二': 84, '生日': '1995/02/08', '平均': 81.0, '年齡': 30}
# {'姓名': '方品絨', '學號': '09', '成績一': 94, '成績二': 82, '生日': '1996/02/25', '平均': 88.0, '年齡': 29}
# {'姓名': '姜冠宏', '學號': '22', '成績一': 72, '成績二': 71, '生日': '1996/03/08', '平均': 71.5, '年齡': 29}
# {'姓名': '王文鴻', '學號': '29', '成績一': 65, '成績二': 60, '生日': '1995/12/07', '平均': 62.5, '年齡': 29}
# {'姓名': '吳辰桀', '學號': '12', '成績一': 91, '成績二': 60, '生日': '1996/11/05', '平均': 75.5, '年齡': 28}
# {'姓名': '李界寬', '學號': '10', '成績一': 69, '成績二': 81, '生日': '1997/06/11', '平均': 75.0, '年齡': 28}
# {'姓名': '吳采曄', '學號': '08', '成績一': 50, '成績二': 96, '生日': '1996/08/25', '平均': 73.0, '年齡': 28}
# {'姓名': '周哲民', '學號': '20', '成績一': 92, '成績二': 92, '生日': '1998/05/12', '平均': 92.0, '年齡': 27}
# {'姓名': '鄭榮仁', '學號': '04', '成績一': 97, '成績二': 83, '生日': '1997/09/03', '平均': 90.0, '年齡': 27}
# {'姓名': '林治宏', '學號': '01', '成績一': 75, '成績二': 87, '生日': '1998/05/22', '平均': 81.0, '年齡': 27}
# {'姓名': '古家宇', '學號': '30', '成績一': 69, '成績二': 73, '生日': '1997/11/03', '平均': 71.0, '年齡': 27}
# {'姓名': '范佐謙', '學號': '14', '成績一': 62, '成績二': 59, '生日': '1997/09/16', '平均': 60.5, '年齡': 27}
# {'姓名': '彭瑋翊', '學號': '19', '成績一': 96, '成績二': 77, '生日': '1999/07/13', '平均': 86.5, '年齡': 26}
# {'姓名': '陳家慶', '學號': '25', '成績一': 91, '成績二': 70, '生日': '2000/03/06', '平均': 80.5, '年齡': 25}
# {'姓名': '王彥傑', '學號': '18', '成績一': 76, '成績二': 51, '生日': '2000/05/24', '平均': 63.5, '年齡': 25}
# {'姓名': '古文晴', '學號': '28', '成績一': 50, '成績二': 77, '生日': '2000/09/19', '平均': 63.5, '年齡': 24}
# {'姓名': '鍾祖培', '學號': '03', '成績一': 61, '成績二': 51, '生日': '2001/01/05', '平均': 56.0, '年齡': 24}
# {'姓名': '劉凡綺', '學號': '26', '成績一': 50, '成績二': 56, '生日': '2000/12/26', '平均': 53.0, '年齡': 24}
# {'姓名': '古智誠', '學號': '11', '成績一': 100, '成績二': 98, '生日': '2001/09/03', '平均': 99.0, '年齡': 23}
# {'姓名': '陳邑溓', '學號': '21', '成績一': 75, '成績二': 87, '生日': '2001/11/24', '平均': 81.0, '年齡': 23}
# {'姓名': '黃連豐', '學號': '27', '成績一': 52, '成績二': 70, '生日': '2002/01/09', '平均': 61.0, '年齡': 23}
# {'姓名': '蘇有', '學號': '31', '成績一': 52, '成績二': 65, '生日': '2002/01/21', '平均': 58.5, '年齡': 23}
# {'姓名': '沈柏臻', '學號': '15', '成績一': 87, '成績二': 97, '生日': '2002/10/01', '平均': 92.0, '年齡': 22}
# {'姓名': '廖天珩', '學號': '05', '成績一': 75, '成績二': 75, '生日': '2002/09/15', '平均': 75.0, '年齡': 22}
# {'姓名': '宋立群', '學號': '06', '成績一': 75, '成績二': 70, '生日': '2003/08/02', '平均': 72.5, '年齡': 22}
# {'姓名': '楊尚謙', '學號': '13', '成績一': 54, '成績二': 67, '生日': '2003/02/06', '平均': 60.5, '年齡': 22}
# {'姓名': '彭明偉', '學號': '23', '成績一': 71, '成績二': 79, '生日': '2003/12/24', '平均': 75.0, '年齡': 21}
# {'姓名': '呂文凱', '學號': '07', '成績一': 67, '成績二': 64, '生日': '2003/12/21', '平均': 65.5, '年齡': 21}
# {'姓名': '徐豪岑', '學號': '17', '成績一': 76, '成績二': 63, '生日': '2004/09/25', '平均': 69.5, '年齡': 20}
# {'姓名': '陳建偉', '學號': '02', '成績一': 60, '成績二': 78, '生日': '2005/08/19', '平均': 69.0, '年齡': 20}
# {'姓名': '陳恩生', '學號': '16', '成績一': 53, '成績二': 90, '生日': '2005/11/21', '平均': 71.5, '年齡': 19}

# %% [markdown]
# ## 字串解析並存入串列結構

# %%
import datetime
f = open('學生資料表.txt', 'r', encoding="UTF-8")
# print(type(f)) # <class '_io.TextIOWrapper'>
# print(dir(f))
data_string = f.read()
# print(repr(a))
f.close()

# 分割字符串為行
lines = data_string.split('\n')

# 創建學生列表（每筆資料是一個子列表）
students = []

for line in lines:
    if line.strip():  # 確保行不為空
        parts = line.split()
        # 將每行數據轉換為列表並添加到students中
        student = [
            parts[0],       # 姓名
            parts[1],       # 學號
            int(parts[2]),   # 成績一
            int(parts[3]),   # 成績二
            parts[4]        # 生日
        ]
        students.append(student)
# 動態新增平均成績元素
for student in students:
    student.append ( ( student[2] + student[3] ) / 2)

# 動態新增年齡元素
for student in students:
    # step1. 把生日字串變成日期結構  'strftime'日期變字串, 'strptime'字串變日期
    我的生日 = datetime.datetime.strptime(student[4],'%Y/%m/%d')
    # step2. 得到今天日期結構
    今天日期 = datetime.datetime.now()
    # step3. 算年齡
    age = 今天日期.year - 我的生日.year
    # step4. 如果生日還沒過  年齡要減一
    if 今天日期 < datetime.datetime(今天日期.year,我的生日.month,我的生日.day) :
        age -= 1
    student.append(age)

# 打印前幾項檢查結果
for student in students:
    #if student[0]=='蘇有' :
    print(student)
        #break
# Out:
# ['林治宏', '01', 75, 87, '1998/05/22', 81.0, 27]
# ['陳建偉', '02', 60, 78, '2005/08/19', 69.0, 20]
# ['鍾祖培', '03', 61, 51, '2001/01/05', 56.0, 24]
# ['鄭榮仁', '04', 97, 83, '1997/09/03', 90.0, 27]
# ['廖天珩', '05', 75, 75, '2002/09/15', 75.0, 22]
# ['宋立群', '06', 75, 70, '2003/08/02', 72.5, 22]
# ['呂文凱', '07', 67, 64, '2003/12/21', 65.5, 21]
# ['吳采曄', '08', 50, 96, '1996/08/25', 73.0, 28]
# ['方品絨', '09', 94, 82, '1996/02/25', 88.0, 29]
# ['李界寬', '10', 69, 81, '1997/06/11', 75.0, 28]
# ['古智誠', '11', 100, 98, '2001/09/03', 99.0, 23]
# ['吳辰桀', '12', 91, 60, '1996/11/05', 75.5, 28]
# ['楊尚謙', '13', 54, 67, '2003/02/06', 60.5, 22]
# ['范佐謙', '14', 62, 59, '1997/09/16', 60.5, 27]
# ['沈柏臻', '15', 87, 97, '2002/10/01', 92.0, 22]
# ['陳恩生', '16', 53, 90, '2005/11/21', 71.5, 19]
# ['徐豪岑', '17', 76, 63, '2004/09/25', 69.5, 20]
# ['王彥傑', '18', 76, 51, '2000/05/24', 63.5, 25]
# ['彭瑋翊', '19', 96, 77, '1999/07/13', 86.5, 26]
# ['周哲民', '20', 92, 92, '1998/05/12', 92.0, 27]
# ['陳邑溓', '21', 75, 87, '2001/11/24', 81.0, 23]
# ['姜冠宏', '22', 72, 71, '1996/03/08', 71.5, 29]
# ['彭明偉', '23', 71, 79, '2003/12/24', 75.0, 21]
# ['詹昇諭', '24', 78, 84, '1995/02/08', 81.0, 30]
# ['陳家慶', '25', 91, 70, '2000/03/06', 80.5, 25]
# ['劉凡綺', '26', 50, 56, '2000/12/26', 53.0, 24]
# ['黃連豐', '27', 52, 70, '2002/01/09', 61.0, 23]
# ['古文晴', '28', 50, 77, '2000/09/19', 63.5, 24]
# ['王文鴻', '29', 65, 60, '1995/12/07', 62.5, 29]
# ['古家宇', '30', 69, 73, '1997/11/03', 71.0, 27]
# ['蘇有', '31', 52, 65, '2002/01/21', 58.5, 23]
